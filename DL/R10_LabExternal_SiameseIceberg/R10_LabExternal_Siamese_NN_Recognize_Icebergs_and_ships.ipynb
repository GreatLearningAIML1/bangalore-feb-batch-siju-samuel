# %% [markdown]
# # Siamese Neural Networks
# Recognize images of icebergs from images of ships.
# These images were taken from space with a Sentinel-4 satellite. The goal was to create the most accurate neural network to differentiate them. However, neural networks usually only work well with A LOT of data, and I constrained you guys to 1000 examples to train on. That seems like a lot, but a CONVENTIONAL neural network needs more data. However, we are going to make a special kind of neural network: *Siamese Network*. This special network is used for face recognition and few-shot learning(learning from few examples). Let's get started by importing the usual liraries:

# %%
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D,Activation, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import Adam
from skimage.io import imshow
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
# Out:
# Using TensorFlow backend.
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/siju/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Load the Data

# %%
npz = np.load('input_data.npz')
X_train = npz['X_train']
Y_train = npz['Y_train']
del npz
print ('We have {} examples to work with'.format(Y_train.shape[0]-1000))
# Out:
# We have 3113 examples to work with

# %% [markdown]
# ## Check the data
#
# Load some of the images to observe how your data look like.

# %%
def check_data(idx):
    imshow(np.squeeze(X_train[idx,:,:,2]))
    plt.show()
    labels = ['Ship','Iceberg']  
    print ('This is:',labels[int(Y_train[idx])])

# %%
check_data(50)
# Out:
# This is: Iceberg

# %%
check_data(220)
# Out:
# This is: Ship

# %%
check_data(300)
# Out:
# This is: Iceberg

# %% [markdown]
# # Creating the structure of Siamese Network

# %% [raw]
# You just need to break it into some steps:
# 1. 2 Inputs for each images
# 2. Creating a network which both images will go through individually
# 3. Couple the network to each input
# 4. Calculate the L1 distance between them. Just (x1,y1)-(x2,y2)
# 5. 1 Added layer that will say 1 if they are the same and 0 if they are different

# %% [markdown]
# # Create two Inputs for each image - left_input and right_input
# Hint - use Input Function in Keras and keep the shape to be 75,75,3

# %%
left_input = Input((75,75,3))
right_input = Input((75,75,3))

# %% [markdown]
# # Create a base Network in which both images will go through individually.
#
# Hint - Use Sequential Model in Keras with convolution layers, Maxpooling Layers, Flatten Layer and Denser Layer with appropriate activation functions.
# Name the network as base_network

# %%
base_network = Sequential([
    Conv2D(5,3, input_shape=(75,75,3)),
    Activation('relu'),
    MaxPooling2D(),
    Conv2D(8,3),
    Activation('relu'),
    MaxPooling2D(),
    Conv2D(10,2),
    Activation('relu'),
    MaxPooling2D(),
    Conv2D(7,2),
    Activation('relu'),
    Flatten(),
    Dense(18),
    Activation('sigmoid')
])
# Out:
# WARNING:tensorflow:From /home/siju/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# # Process the left and right inputs to the same Base Network(base_network)

# %%
processed_a = base_network(left_input)

# %%
processed_b = base_network(right_input)

# %% [markdown]
# # Get the L1 Distance layer between the 2 processed encodings (processed_a and processed_b)
# Hint - You can use Lambda function for this.

# %%
# Getting the L1 Distance between the 2 encodings
L1_layer = Lambda(lambda tensor:K.abs(tensor[0] - tensor[1]))

# %%
# Add the distance function to the network
L1_distance = L1_layer([processed_a, processed_b])

# %% [markdown]
# # Add the prediction layer in the end and create the Siamese Network using Model function.

# %%
prediction = Dense(1,activation='sigmoid')(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

# %% [markdown]
# # Define the Optimizer Adam and Compile the Siamese Model.

# %%
optimizer = Adam(0.001, decay=2.5e-4)

siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/siju/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Show the Summary of your Siamese Network

# %%
siamese_net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 75, 75, 3)    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 75, 75, 3)    0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 18)           7317        input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 18)           0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            19          lambda_1[0][0]
# ==================================================================================================
# Total params: 7,336
# Trainable params: 7,336
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Creating the Pair of Images to train on

# %% [markdown]
# It's not time to train though. We still have to create pairs of images to train on. There will be Positive(the same class) or Negative(different classes) for outputs. Let's construct this dataset. It is recommended that there are equal amounts positive and negative.

# %%
# First let's separate the dataset from 1 matrix to a list of matricies
image_list = np.split(X_train[:1000],1000)
label_list = np.split(Y_train[:1000],1000)

left_input = []
right_input = []
targets = []

#Number of pairs per image
pairs = 5
#Let's create the new dataset to train on
for i in range(len(label_list)):
    for _ in range(pairs):
        compare_to = i
        while compare_to == i: #Make sure it's not comparing to itself
            compare_to = random.randint(0,999)
        left_input.append(image_list[i])
        right_input.append(image_list[compare_to])
        if label_list[i] == label_list[compare_to]:# They are the same
            targets.append(1.)
        else:# Not the same
            targets.append(0.)
            
left_input = np.squeeze(np.array(left_input))
right_input = np.squeeze(np.array(right_input))
targets = np.squeeze(np.array(targets))

iceimage = X_train[101]
test_left = []
test_right = []
test_targets = []

for i in range(Y_train.shape[0]-1000):
    test_left.append(iceimage)
    test_right.append(X_train[i+1000])
    test_targets.append(Y_train[i+1000])

test_left = np.squeeze(np.array(test_left))
test_right = np.squeeze(np.array(test_right))
test_targets = np.squeeze(np.array(test_targets))

# %% [markdown]
# Now we have a lot more examples.
# Now we have pairs x 1000 examples to train the network on.
# Each side will have an input of an image and the output will be one if they are the same and zero if not.

# %% [markdown]
# # Train the Siamese train on left and right input image pairs created and validate it by test pairs.

# %%
callbacks = [
    EarlyStopping(patience=20, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr= 0.001, verbose=1),
    ModelCheckpoint('siamese_model.h5', verbose=1, save_best_only=True)
]

# %%
siamese_net.fit([left_input,right_input], targets,
                batch_size=16,
                epochs=60,
                verbose=1,
                validation_data=([test_left,test_right],test_targets),
                callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /home/siju/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 5000 samples, validate on 3113 samples
# Epoch 1/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.6767 - accuracy: 0.5664 - val_loss: 0.6892 - val_accuracy: 0.5259
#
# Epoch 00001: val_loss improved from inf to 0.68920, saving model to siamese_model.h5
# Epoch 2/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.6324 - accuracy: 0.6460 - val_loss: 0.5542 - val_accuracy: 0.7697
#
# Epoch 00002: val_loss improved from 0.68920 to 0.55417, saving model to siamese_model.h5
# Epoch 3/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.5963 - accuracy: 0.6980 - val_loss: 0.5114 - val_accuracy: 0.7729
#
# Epoch 00003: val_loss improved from 0.55417 to 0.51136, saving model to siamese_model.h5
# Epoch 4/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.5582 - accuracy: 0.7306 - val_loss: 0.4982 - val_accuracy: 0.7748
#
# Epoch 00004: val_loss improved from 0.51136 to 0.49819, saving model to siamese_model.h5
# Epoch 5/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.5194 - accuracy: 0.7610 - val_loss: 0.5193 - val_accuracy: 0.7549
#
# Epoch 00005: val_loss did not improve from 0.49819
# Epoch 6/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.4781 - accuracy: 0.7932 - val_loss: 0.5790 - val_accuracy: 0.7125
#
# Epoch 00006: val_loss did not improve from 0.49819
# Epoch 7/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.4520 - accuracy: 0.8052 - val_loss: 0.5189 - val_accuracy: 0.7591
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00007: val_loss did not improve from 0.49819
# Epoch 8/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.4189 - accuracy: 0.8304 - val_loss: 0.5047 - val_accuracy: 0.7803
#
# Epoch 00008: val_loss did not improve from 0.49819
# Epoch 9/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.3966 - accuracy: 0.8404 - val_loss: 0.5564 - val_accuracy: 0.7417
#
# Epoch 00009: val_loss did not improve from 0.49819
# Epoch 10/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.3828 - accuracy: 0.8442 - val_loss: 0.5077 - val_accuracy: 0.7771
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00010: val_loss did not improve from 0.49819
# Epoch 11/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.3520 - accuracy: 0.8632 - val_loss: 0.5723 - val_accuracy: 0.7433
#
# Epoch 00011: val_loss did not improve from 0.49819
# Epoch 12/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.3392 - accuracy: 0.8694 - val_loss: 0.5506 - val_accuracy: 0.7594
#
# Epoch 00012: val_loss did not improve from 0.49819
# Epoch 13/60
# 5000/5000 [==============================] - 8s 2ms/step - loss: 0.3199 - accuracy: 0.8830 - val_loss: 0.5648 - val_accuracy: 0.7584
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00013: val_loss did not improve from 0.49819
# Epoch 14/60
# 5000/5000 [==============================] - 8s 2ms/step - loss: 0.3077 - accuracy: 0.8882 - val_loss: 0.5496 - val_accuracy: 0.7684
#
# Epoch 00014: val_loss did not improve from 0.49819
# Epoch 15/60
# 5000/5000 [==============================] - 8s 2ms/step - loss: 0.2945 - accuracy: 0.8914 - val_loss: 0.5854 - val_accuracy: 0.7488
#
# Epoch 00015: val_loss did not improve from 0.49819
# Epoch 16/60
# 5000/5000 [==============================] - 8s 2ms/step - loss: 0.2816 - accuracy: 0.8982 - val_loss: 0.5922 - val_accuracy: 0.7546
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.49819
# Epoch 17/60
# 5000/5000 [==============================] - 8s 2ms/step - loss: 0.2701 - accuracy: 0.9024 - val_loss: 0.5839 - val_accuracy: 0.7600
#
# Epoch 00017: val_loss did not improve from 0.49819
# Epoch 18/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2604 - accuracy: 0.9108 - val_loss: 0.6100 - val_accuracy: 0.7559
#
# Epoch 00018: val_loss did not improve from 0.49819
# Epoch 19/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2497 - accuracy: 0.9144 - val_loss: 0.5935 - val_accuracy: 0.7674
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00019: val_loss did not improve from 0.49819
# Epoch 20/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2419 - accuracy: 0.9158 - val_loss: 0.6030 - val_accuracy: 0.7642
#
# Epoch 00020: val_loss did not improve from 0.49819
# Epoch 21/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2323 - accuracy: 0.9174 - val_loss: 0.6793 - val_accuracy: 0.7331
#
# Epoch 00021: val_loss did not improve from 0.49819
# Epoch 22/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2351 - accuracy: 0.9150 - val_loss: 0.6718 - val_accuracy: 0.7359
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00022: val_loss did not improve from 0.49819
# Epoch 23/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2189 - accuracy: 0.9236 - val_loss: 0.5790 - val_accuracy: 0.7755
#
# Epoch 00023: val_loss did not improve from 0.49819
# Epoch 24/60
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.2115 - accuracy: 0.9268 - val_loss: 0.6809 - val_accuracy: 0.7433
#
# Epoch 00024: val_loss did not improve from 0.49819
# Epoch 00024: early stopping

# %%
siamese_net.load_weights('siamese_model.h5')

# %%
val_loss, val_acc = siamese_net.evaluate([test_left,test_right], 
                     test_targets,
                     batch_size=16,
                     verbose=1)
# Out:
# 3113/3113 [==============================] - 2s 550us/step

# %%
print("Validation Loss =", val_loss)
print("Validation Accuracy =", val_acc)
# Out:
# Validation Loss = 0.49818950690451136
# Validation Accuracy = 0.7748152613639832
